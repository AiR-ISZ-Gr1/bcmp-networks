# %%
from bcmp.plots import avg_requests_per_class, procces_time_all_servers

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_json('/home/bartoszworklinux/std/bcmp-networks/logs/vcXXWKIftD.jsonl', lines=True)

# %%
avg_requests_per_class(data)
# Out:
# 2024-11-13 19:22:56.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-13 19:22:56.920
# ...
#   command:
#
#     streamlit run /home/bartoszworklinux/std/bcmp-networks/.venv/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-11-13 19:22:56.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
procces_time_all_servers(data)
# Out:
# No valid processing times for source subset.
# /home/bartoszworklinux/std/bcmp-networks/src/bcmp/plots/plots.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_subset['ts'] = pd.to_timedelta(data_subset['ts'])
